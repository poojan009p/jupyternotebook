# %% [markdown]
# # MY WORKING STRUCTURE IN JUPYTER NOTEBOOK

# %% [markdown]
# ---

# %% [markdown]
# # Project Title
#
# ## Objective
# What problem are we solving?
#
# ## Dataset
# Source of the data.
#
# ## Workflow
# 1. Import Libraries
# 2. Load Data
# 3. Data Understanding
# 4. Data Cleaning
# 5. Exploratory Data Analysis
# 6. Feature Engineering
# 7. Modeling (if applicable)
# 8. Conclusion

# %% [markdown]
# ## Project Workflow
#
# Raw Data
#     ↓
# Data Cleaning
#     ↓
# EDA
#     ↓
# Feature Engineering
#     ↓
# Model Training
#     ↓
# Evaluation
#     ↓
# Business Insights
